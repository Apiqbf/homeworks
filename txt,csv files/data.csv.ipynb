# %%
import csv
with open("txt,csv files/data.csv", "w", newline="", encoding="utf-8")as c:
    c.write("hello world")

# %%
import csv
numbers=[435,326,344]
names=["erasyl","temirlan","asylai"]
with open("txt,csv files/numbers.csv", "a", newline="", encoding="utf-8")as c:
    for n in numbers:
        c.write(str(n)+"\n")

# %%
import csv
names=["erasyl","temirlan","asylai"]
with open("txt,csv files/names.csv", "w", newline="", encoding="utf-8")as c:
    for n in names:
        c.write(n.capitalize()+"\n")

# %%
with open("txt,csv files/numbers.csv", "r", newline="", encoding="utf-8")as b:
    r=b.read()
    print(r)

with open("txt,csv files/names.csv", "r", newline="", encoding="utf-8")as b:
    rr=b.read()
    print(rr)
# Out:
# 435
# 326
# 344
#
# Erasyl
# Temirlan
# Asylai
