# %%
#LAMBDA функции

# %%
#1
check=lambda x:
# Out:
#   Cell In[3], line 2
#     check=lambda x:print("положительное") if x>0,print("отрицательное") if x<0,else print("ноль")
#                    ^
# SyntaxError: expected 'else' after 'if' expression
